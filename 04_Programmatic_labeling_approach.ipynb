# %% [markdown]
# # Approach 4 (Programmatic Labeling)

# %% [markdown]
# #### Load Data

# %%
import json
import pandas as pd
import re
from collections import Counter, defaultdict
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier
import Levenshtein
from sklearn.metrics import classification_report, accuracy_score

# Load JSON
with open("linkedin-cvs-annotated.json", "r", encoding="utf-8") as f:
    annotated_cvs = json.load(f)

with open("linkedin-cvs-not-annotated.json", "r", encoding="utf-8") as f:
    not_annotated_cvs = json.load(f)

# Load CVs
df_dept = pd.read_csv("department-v2.csv")
df_sen  = pd.read_csv("seniority-v2.csv")

# %% [markdown]
# #### Text Normalization

# %%
def normalize(text):
    if pd.isna(text):
        return ""
    text = str(text).lower()

    # Normalize umlauts
    text = (
        text.replace("ä","ae")
            .replace("ö","oe")
            .replace("ü","ue")
            .replace("ß","ss")
    )

    # Remove gendered forms: managerin -> manager
    text = re.sub(r"(in|innen|in$)", "", text)

    # Remove special characters
    text = re.sub(r"[^a-z0-9 ]", " ", text)

    # Remove multiple spaces
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %% [markdown]
# #### DB-Lookup

# %%
# Apply text normalization to job titles in the lookup tables
df_dept["text_clean"] = df_dept["text"].apply(normalize)
df_sen["text_clean"]  = df_sen["text"].apply(normalize)

# Build lookup dictionaries
dept_lookup = dict(zip(df_dept["text_clean"], df_dept["label"]))
sen_lookup  = dict(zip(df_sen["text_clean"], df_sen["label"]))

# %% [markdown]
# #### Seniority and Department Keywords

# %%
# Define a set of stopwords to exclude non-informative words
stopwords = set(["and","of","for","und","der","die","das","in","mit","to","de","la","le","des","et","en","as"])

def build_keyword_dict(df):
    # Collect words per label
    label_words = defaultdict(list)

    for _, row in df.iterrows():
        label = row["label"]
        text = normalize(row["text"])
        words = text.split()

        for w in words:
            # Keep only meaningful words (min length 3, not a stopword)
            if len(w) >= 3 and w not in stopwords:
                label_words[label].append(w)

    keyword_dict = {}
    for label, words in label_words.items():
        # Count word frequencies and keep the most common ones per label
        counts = Counter(words)
        keyword_dict[label] = dict(counts.most_common(30))

    return keyword_dict

# Build keyword dictionaries for seniority and department
sen_keywords  = build_keyword_dict(df_sen)
dept_keywords = build_keyword_dict(df_dept)

# %% [markdown]
# #### Abbreviations for Seniority and Department

# %%
seniority_abbr = {
    "jr": "Junior",
    "jnr": "Junior",
    "lead": "Lead",
    "ld": "Lead",
    "dir": "Director",
    "dr": "Director",
    "mgr": "Management",
    "mgmt": "Management",
    "manag": "Management",
    "head": "Management",
    "sr": "Senior",
    "snr": "Senior",
    "chief": "Lead",
    "vp": "Director"
}


department_abbr = {
    "mkt": "Marketing",
    "mktg": "Marketing",
    "sales": "Sales",
    "sls": "Sales",
    "it": "Information Technology",
    "bd": "Business Development",
    "pm": "Project Management",
    "cons": "Consulting",
    "cnsltg": "Consulting",
    "admin": "Administrative",
    "adm": "Administrative",
    "other": "Other",
    "purch": "Purchasing",
    "prch": "Purchasing",
    "cs": "Customer Support",
    "cust sup": "Customer Support",
    "cust support": "Customer Support",
    "hr": "Human Resources",
    "fin": "Finance",
    "ops": "Operations",
    "r&d": "Research & Development"
}

# %% [markdown]
# #### Length Heuristic

# %%
sen_stats = df_sen.copy()
# Calculate the word count for each job title
sen_stats["words"] = sen_stats["text"].apply(lambda x: len(str(x).split()))
# Compute the average word count per seniority label
sen_threshold = sen_stats.groupby("label")["words"].mean()

def length_based_seniority(position):
    words = len(position.split())
    if words <= 3:
        return "Junior"
    elif words >= 6:
        return "Senior"
    return None

# %% [markdown]
# #### C-Level Abbreviations

# %%
c_level_abbr = {
    "CEO": "Chief Executive Officer",
    "CFO": "Chief Financial Officer",
    "COO": "Chief Operating Officer",
    "CTO": "Chief Technology Officer",
    "CMO": "Chief Marketing Officer",
    "CIO": "Chief Information Officer",
    "CHRO": "Chief Human Resources Officer",
    "CDO": "Chief Digital Officer / Chief Data Officer",
    "CRO": "Chief Revenue Officer",
    "CSO": "Chief Sales Officer / Chief Strategy Officer",
    "CAO": "Chief Administrative Officer",
    "CCO": "Chief Commercial Officer / Chief Compliance Officer",
    "CLO": "Chief Legal Officer / Chief Learning Officer",
    "CPO": "Chief Product Officer / Chief People Officer",
    "EVP": "Executive Vice President",
    "SVP": "Senior Vice President",
    "VP": "Vice President",
    "AVP": "Assistant / Associate Vice President"
}

# %% [markdown]
# #### Levenshtein Distance (for Typographical Errors)

# %%
def edit_distance_label(pos, keywords_dict, max_distance=2):
    pos_norm = normalize(pos)
    words = pos_norm.split()  

    for word in words: 
        for label, kws in keywords_dict.items():
            for kw in kws:
                if Levenshtein.distance(word, kw) <= max_distance:
                    return label  

    return None

# %% [markdown]
# #### Labeling Function with Majority Voting

# %%
def vote(labels):
    labels = [l for l in labels if l is not None]
    if len(labels) == 0:
        return None
    return Counter(labels).most_common(1)[0][0]


def label_position(position):
    # Normalize the job title
    pos = normalize(position)

    # Lookup (hard priority)
    sen_lookup_match  = sen_lookup.get(pos)
    dept_lookup_match = dept_lookup.get(pos)

  
    # Case A: both lookups match
  
    if sen_lookup_match is not None and dept_lookup_match is not None:
        return sen_lookup_match, dept_lookup_match

   
    # Case B: only seniority lookup matches
 
    elif sen_lookup_match is not None and dept_lookup_match is None:
        final_sen = sen_lookup_match

        dept_votes = []

        # Keyword matching for department
        for label, kws in dept_keywords.items():
            for kw in kws:
                if kw in pos:
                    dept_votes.append(label)

        # Fuzzy matching for department
        lev_dept = edit_distance_label(pos, dept_keywords, max_distance=2)
        if lev_dept:
            dept_votes.append(lev_dept)

        # Abbreviation matching for department
        for abbr, lab in department_abbr.items():
            if abbr.lower() in pos.lower():
                dept_votes.append(lab)

        # Majority voting for department
        final_dept = vote(dept_votes)
        if final_dept is None:
            final_dept = "Other"

        return final_sen, final_dept

 
    # Case C: only department lookup matches
   
    elif sen_lookup_match is None and dept_lookup_match is not None:
        final_dept = dept_lookup_match

        sen_votes = []

        # Keyword matching for seniority
        for label, kws in sen_keywords.items():
            for kw in kws:
                if kw in pos:
                    sen_votes.append(label)

        # Fuzzy matching for seniority
        lev_sen = edit_distance_label(pos, sen_keywords, max_distance=1)
        if lev_sen:
            sen_votes.append(lev_sen)

        # Abbreviation matching for seniority
        for abbr, lab in seniority_abbr.items():
            if abbr.lower() in pos.lower():
                sen_votes.append(lab)

        # C-level title detection (forces Management)
        for abbr, lab in c_level_abbr.items():
            if abbr.lower() in pos.lower() or lab.lower() in pos.lower():
                sen_votes.append("Management")

        # Length-based fallback for seniority
        if len(sen_votes) == 0:
            sen_votes.append(length_based_seniority(pos))

        # Majority voting for seniority
        final_sen = vote(sen_votes)

        return final_sen, final_dept


    # Case D: no lookup matches
  
    else:
        sen_votes  = []
        dept_votes = []

        # Keyword matching
        for label, kws in sen_keywords.items():
            for kw in kws:
                if kw in pos:
                    sen_votes.append(label)

        for label, kws in dept_keywords.items():
            for kw in kws:
                if kw in pos:
                    dept_votes.append(label)

        # Fuzzy matching
        lev_sen = edit_distance_label(pos, sen_keywords, max_distance=1)
        if lev_sen:
            sen_votes.append(lev_sen)

        lev_dept = edit_distance_label(pos, dept_keywords, max_distance=2)
        if lev_dept:
            dept_votes.append(lev_dept)

        # Abbreviation matching
        for abbr, lab in seniority_abbr.items():
            if abbr.lower() in pos.lower():
                sen_votes.append(lab)

        for abbr, lab in department_abbr.items():
            if abbr.lower() in pos.lower():
                dept_votes.append(lab)

        # C-level title detection (forces Management)
        for abbr, lab in c_level_abbr.items():
            if abbr.lower() in pos.lower() or lab.lower() in pos.lower():
                sen_votes.append("Management")

        # Length-based fallback for seniority
        if len(sen_votes) == 0:
            sen_votes.append(length_based_seniority(pos))

        # Majority voting
        final_sen  = vote(sen_votes)
        final_dept = vote(dept_votes)
        if final_dept is None:
            final_dept = "Other"

        return final_sen, final_dept

# %% [markdown]
# #### Automatically Label JSON (not-annotated)

# %%
# Prepare training data for the model
X = [] # Features / input texts (job titles)
y_sen = [] #Target variable: Seniority
y_dept = [] # Target variable: Department

# Iterate through each LinkedIn CV in the non-annotated file
# Only current positions are considered, since we only want to predict current seniority and department
for cv in not_annotated_cvs:
    for job in cv:
        if job["status"] == "ACTIVE":
            sen_label, dept_label = label_position(job["position"])
            job["pred_seniority"] = sen_label
            job["pred_department"] = dept_label

            X.append(normalize(job["position"]))
            y_sen.append(sen_label)
            y_dept.append(dept_label)

print("Training Examples:", len(X))
# Out:
# Training Examples: 419

# %% [markdown]
# #### Train ML models

# %%
# Clean data: only complete labels
X_clean = []
y_sen_clean = []
y_dept_clean = []

# Remove training examples where Seniority or Department is missing
for x, y_sen_item, y_dept_item in zip(X, y_sen, y_dept):
    if y_sen_item is not None and y_dept_item is not None:
        X_clean.append(x)
        y_sen_clean.append(y_sen_item)
        y_dept_clean.append(y_dept_item)

print(f"Filtered training examples: {len(X_clean)}")
if len(X_clean) == 0:
    raise ValueError("No training data left after filtering None labels.")


# 1) Seniority Classification ---------------------------------------------------------------------------------------------------------------------------------------------------------


# Train test split
X_train_sen, X_test_sen, y_train_sen, y_test_sen = train_test_split(
    X_clean, y_sen_clean, test_size=0.3, random_state=42
)

# Convert job titles to numerical features
vec_sen = TfidfVectorizer(ngram_range=(1, 2))
X_train_vec_sen = vec_sen.fit_transform(X_train_sen)
X_test_vec_sen  = vec_sen.transform(X_test_sen)

# Train logistic regression classifier
clf_sen = LogisticRegression(max_iter=1000)
clf_sen.fit(X_train_vec_sen, y_train_sen)

# In-sample predictions
train_preds_sen = clf_sen.predict(X_train_vec_sen)
train_acc_sen = accuracy_score(y_train_sen, train_preds_sen)
print("Seniority In-sample Accuracy (Training):", train_acc_sen)
print("Seniority In-sample Classification Report:\n", classification_report(y_train_sen, train_preds_sen))

# Out-of-sample predictions
test_preds_sen = clf_sen.predict(X_test_vec_sen)
test_acc_sen = accuracy_score(y_test_sen, test_preds_sen)
print("Seniority Out-of-sample Accuracy (Test):", test_acc_sen)
print("Seniority Out-of-sample Classification Report:\n", classification_report(y_test_sen, test_preds_sen))



# 2) Department Classification ------------------------------------------------------------------------------------------------------------------------------------------------------------

# Train test split
X_train_dept, X_test_dept, y_train_dept, y_test_dept = train_test_split(
    X_clean, y_dept_clean, test_size=0.3, random_state=42
)

# Convert job titles to numerical features
vec_dept = TfidfVectorizer(ngram_range=(1, 2))
X_train_vec_dept = vec_dept.fit_transform(X_train_dept)
X_test_vec_dept  = vec_dept.transform(X_test_dept)

# Train logistic regression classfier
clf_dept = LogisticRegression(max_iter=1000)
clf_dept.fit(X_train_vec_dept, y_train_dept)

# In-sample predictions
train_preds_dept = clf_dept.predict(X_train_vec_dept)
train_acc_dept = accuracy_score(y_train_dept, train_preds_dept)
print("\n Department In-sample Accuracy (Training):", train_acc_dept)
print("Department In-sample Classification Report:\n", classification_report(y_train_dept, train_preds_dept))

# Out-of-sample predictions
test_preds_dept = clf_dept.predict(X_test_vec_dept)
test_acc_dept = accuracy_score(y_test_dept, test_preds_dept)
print("Department Out-of-sample Accuracy (Test):", test_acc_dept)
print("Department Out-of-sample Classification Report:\n", classification_report(y_test_dept, test_preds_dept))
# Out:
# Filtered training examples: 410
# Seniority In-sample Accuracy (Training): 0.9024390243902439
# Seniority In-sample Classification Report:
#                precision    recall  f1-score   support
#
#     Director       1.00      0.60      0.75        25
#       Junior       0.79      1.00      0.88        87
#         Lead       1.00      0.26      0.41        23
#   Management       0.99      1.00      0.99        83
#       Senior       0.94      0.99      0.96        69
#
#     accuracy                           0.90       287
#    macro avg       0.94      0.77      0.80       287
# weighted avg       0.92      0.90      0.89       287
#
# Seniority Out-of-sample Accuracy (Test): 0.7804878048780488
# Seniority Out-of-sample Classification Report:
#                precision    recall  f1-score   support
#
#     Director       0.67      0.67      0.67         9
#       Junior       0.67      0.86      0.76        43
#         Lead       1.00      0.25      0.40        16
#   Management       1.00      0.83      0.91        29
#       Senior       0.81      0.96      0.88        26
#
#     accuracy                           0.78       123
#    macro avg       0.83      0.71      0.72       123
# weighted avg       0.82      0.78      0.76       123
#
#
#  Department In-sample Accuracy (Training): 0.7247386759581882
# Department In-sample Classification Report:
#                          precision    recall  f1-score   support
#
#         Administrative       1.00      0.79      0.88        29
#   Business Development       1.00      0.71      0.83        28
#             Consulting       0.00      0.00      0.00        14
#       Customer Support       1.00      0.43      0.60         7
#        Human Resources       1.00      0.78      0.88         9
# Information Technology       0.00      0.00      0.00        14
#              Marketing       0.77      0.99      0.86        68
#                  Other       0.58      1.00      0.74        83
#     Project Management       1.00      0.24      0.38        21
#             Purchasing       0.00      0.00      0.00         4
#                  Sales       0.00      0.00      0.00        10
#
#               accuracy                           0.72       287
#              macro avg       0.58      0.45      0.47       287
#           weighted avg       0.68      0.72      0.66       287
#
# Department Out-of-sample Accuracy (Test): 0.6422764227642277
# Department Out-of-sample Classification Report:
#                          precision    recall  f1-score   support
#
#         Administrative       1.00      0.62      0.77         8
#   Business Development       0.60      0.67      0.63         9
#             Consulting       0.00      0.00      0.00         7
#       Customer Support       1.00      0.50      0.67         2
#        Human Resources       1.00      0.33      0.50         3
# Information Technology       0.00      0.00      0.00         6
#              Marketing       0.69      0.90      0.78        39
#                  Other       0.56      0.91      0.70        34
#     Project Management       0.00      0.00      0.00         6
#             Purchasing       0.00      0.00      0.00         5
#                  Sales       0.00      0.00      0.00         4
#
#               accuracy                           0.64       123
#              macro avg       0.44      0.36      0.37       123
#           weighted avg       0.52      0.64      0.56       123
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# #### Final Evaluation with Annotated JSON File

# %%
# Extract all active jobs from the annotated JSON
annotated_jobs = []
for cv in annotated_cvs:
    for job in cv:
        if job["status"] == "ACTIVE":
            annotated_jobs.append(job)

df_val = pd.DataFrame(annotated_jobs)

# Normalize texts
df_val["position_clean"] = df_val["position"].apply(normalize)


# The TF-IDF vectors are reused to map test/validation data to the same feature space, so that the already trained model can make predictions
X_val_vec_sen  = vec_sen.transform(df_val["position_clean"])
X_val_vec_dept = vec_dept.transform(df_val["position_clean"])

# Generate predictions
val_preds_sen  = clf_sen.predict(X_val_vec_sen)
val_preds_dept = clf_dept.predict(X_val_vec_dept)

# True labels from the annotated JSON
y_val_true_sen  = df_val["seniority"]
y_val_true_dept = df_val["department"]

# Calculate accuracy
acc_sen  = accuracy_score(y_val_true_sen, val_preds_sen)
acc_dept = accuracy_score(y_val_true_dept, val_preds_dept)


print("SnapAddy Validation Accuracy")
print(f"Seniority Accuracy: {acc_sen:.2%}")
print(f"Department Accuracy: {acc_dept:.2%}\n")

print("Seniority Classification Report:\n", classification_report(y_val_true_sen, val_preds_sen))
print("Department Classification Report:\n", classification_report(y_val_true_dept, val_preds_dept))
# Out:
# SnapAddy Validation Accuracy
# Seniority Accuracy: 31.78%
# Department Accuracy: 38.68%
#
# Seniority Classification Report:
#                precision    recall  f1-score   support
#
#     Director       0.53      0.68      0.60        34
#       Junior       0.04      1.00      0.08        12
#         Lead       1.00      0.05      0.09       125
#   Management       0.98      0.62      0.76       192
# Professional       0.00      0.00      0.00       216
#       Senior       0.23      0.86      0.37        44
#
#     accuracy                           0.32       623
#    macro avg       0.46      0.53      0.32       623
# weighted avg       0.55      0.32      0.31       623
#
# Department Classification Report:
#                          precision    recall  f1-score   support
#
#         Administrative       0.00      0.00      0.00        14
#   Business Development       0.41      0.45      0.43        20
#             Consulting       0.00      0.00      0.00        39
#       Customer Support       0.00      0.00      0.00         6
#        Human Resources       0.00      0.00      0.00        16
# Information Technology       0.00      0.00      0.00        62
#              Marketing       0.06      0.59      0.10        22
#                  Other       0.66      0.63      0.65       344
#     Project Management       0.33      0.03      0.05        39
#             Purchasing       0.00      0.00      0.00        15
#                  Sales       0.00      0.00      0.00        46
#
#               accuracy                           0.39       623
#              macro avg       0.13      0.15      0.11       623
#           weighted avg       0.40      0.39      0.38       623
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\vikto\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# #### Error Analysis

# %%
def analyze_errors(true_labels, pred_labels, positions, title="Error Analysis"):
    errors = defaultdict(list)
    for i, (true, pred) in enumerate(zip(true_labels, pred_labels)):
        if true != pred:
            errors[true].append((positions[i], pred))

    print(f"\n{title}")
    for label, instances in errors.items():
        print(f"\nLabel '{label}' was incorrectly predicted {len(instances)} times:")
        for pos, pred in instances:
            print(f"  Position: '{pos}' → Predicted: '{pred}'")

# Error analysis for Seniority
analyze_errors(y_val_true_sen, val_preds_sen, df_val["position_clean"], title="Seniority Error Analysis")

# Error analysis for Department
analyze_errors(y_val_true_dept, val_preds_dept, df_val["position_clean"], title="Department Error Analysis")
# Out:
# Seniority Error Analysis
#
# Label 'Management' was incorrectly predicted 73 times:
#   Position: 'prokurist' → Predicted: 'Junior'
#   Position: 'cfo' → Predicted: 'Junior'
#   Position: 'prokurist' → Predicted: 'Junior'
#   Position: 'cfo' → Predicted: 'Junior'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'member of the advisory board' → Predicted: 'Junior'
#   Position: 'member of the advisory board' → Predicted: 'Junior'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'kurucu ortak' → Predicted: 'Junior'
#   Position: 'eigenaar' → Predicted: 'Junior'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'board member cfo asset management' → Predicted: 'Junior'
#   Position: 'arbeitgeber' → Predicted: 'Junior'
#   Position: 'kanzler cfo' → Predicted: 'Junior'
#   Position: 'member of the board frankfurt school stiftung' → Predicted: 'Junior'
#   Position: 'managg partner group managg board' → Predicted: 'Senior'
#   Position: 'vorsitzender des vorstandes' → Predicted: 'Junior'
#   Position: 'managg dircector' → Predicted: 'Senior'
#   Position: 'executive director marketg strategy director' → Predicted: 'Director'
#   Position: 'krankenhausgeschaeftsfuehrer' → Predicted: 'Junior'
#   Position: 'cto' → Predicted: 'Junior'
#   Position: 'verwaltungsratsvorsitzender' → Predicted: 'Junior'
#   Position: 'aufsichtsrat' → Predicted: 'Junior'
#   Position: 'president of the board of directors' → Predicted: 'Junior'
#   Position: 'chairman of board of appeal and member of enlarged board of appeal' → Predicted: 'Junior'
#   Position: 'algemeen directeur' → Predicted: 'Junior'
#   Position: 'executive director' → Predicted: 'Director'
#   Position: 'global vp and head of sustaability novation' → Predicted: 'Senior'
#   Position: 'kfm prokurist' → Predicted: 'Junior'
#   Position: 'entrepreneur general et consultat construction' → Predicted: 'Senior'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'cto' → Predicted: 'Junior'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'general manager' → Predicted: 'Senior'
#   Position: 'vorstandsmitglied' → Predicted: 'Junior'
#   Position: 'geschaeftsfueherer' → Predicted: 'Junior'
#   Position: 'general manager' → Predicted: 'Senior'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'vp product management' → Predicted: 'Senior'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'board member' → Predicted: 'Junior'
#   Position: 'vice president national sales manager' → Predicted: 'Senior'
#   Position: 'general manager' → Predicted: 'Senior'
#   Position: 'mitglied des aufsichtsrats' → Predicted: 'Junior'
#   Position: 'vorstandsmitglied' → Predicted: 'Junior'
#   Position: 'aegare affaersomr deschef it cto' → Predicted: 'Junior'
#   Position: 'grundare aegare' → Predicted: 'Junior'
#   Position: 'managg director cto' → Predicted: 'Director'
#   Position: 'managg director co founder' → Predicted: 'Director'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'vorstandsassistent cmo' → Predicted: 'Junior'
#   Position: 'co executive director' → Predicted: 'Director'
#   Position: 'geschaeftsfuehrer berater designer' → Predicted: 'Junior'
#   Position: 'general manager vice president of planng' → Predicted: 'Senior'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'managg director' → Predicted: 'Director'
#   Position: 'vp purchasg supplier quality webasto cha' → Predicted: 'Junior'
#   Position: 'non executive director member of the supervisory board' → Predicted: 'Director'
#   Position: 'non executive director member of the supervisory board' → Predicted: 'Director'
#   Position: 'vorsitzender der aufsichtsraete mecklenburgische versicherungen' → Predicted: 'Junior'
#   Position: 'geschaeftsfuehrer general manager' → Predicted: 'Senior'
#   Position: 'managg partner' → Predicted: 'Senior'
#   Position: 'mitglied der geschaeftsleitung' → Predicted: 'Junior'
#   Position: 'general manager' → Predicted: 'Senior'
#   Position: 'mitgruender' → Predicted: 'Junior'
#   Position: 'eigenaar' → Predicted: 'Junior'
#   Position: 'eigenaar' → Predicted: 'Junior'
#   Position: 'member board of directors' → Predicted: 'Junior'
#   Position: 'pr sident ccrg hauts de france' → Predicted: 'Junior'
#   Position: 'kanzler der deutschen assoziation' → Predicted: 'Junior'
#   Position: 'praesidium' → Predicted: 'Junior'
#
# Label 'Professional' was incorrectly predicted 216 times:
#   Position: 'betriebswirt' → Predicted: 'Junior'
#   Position: 'solutions architect' → Predicted: 'Junior'
#   Position: 'mediztechnik beratung' → Predicted: 'Junior'
#   Position: 'admistrador unico' → Predicted: 'Junior'
#   Position: 'human resources generalist' → Predicted: 'Junior'
#   Position: 'set lightg' → Predicted: 'Junior'
#   Position: 'set lightg' → Predicted: 'Junior'
#   Position: 'set lightg' → Predicted: 'Junior'
#   Position: 'set lightg' → Predicted: 'Junior'
#   Position: 'set lightg' → Predicted: 'Junior'
#   Position: 'projektmanager' → Predicted: 'Junior'
#   Position: 'leistungssachbearbeiter sgb ii' → Predicted: 'Junior'
#   Position: 'energy and sustaability consultant bei' → Predicted: 'Senior'
#   Position: 'purchasg manager' → Predicted: 'Senior'
#   Position: 'dr phil' → Predicted: 'Junior'
#   Position: 'physician assistant' → Predicted: 'Junior'
#   Position: 'qualifizierter kreditsachbearbeiter im risikorelevanten kreditgeschaeft' → Predicted: 'Junior'
#   Position: 'it systems and network engeer' → Predicted: 'Senior'
#   Position: 'it systemadmistrator' → Predicted: 'Junior'
#   Position: 'human resources consultant' → Predicted: 'Senior'
#   Position: 'product manager' → Predicted: 'Senior'
#   Position: 'reporter' → Predicted: 'Junior'
#   Position: 'waiter bartender' → Predicted: 'Junior'
#   Position: 'busess development manager' → Predicted: 'Senior'
#   Position: 'i guevenli i' → Predicted: 'Junior'
#   Position: 'museumspaedagoge' → Predicted: 'Junior'
#   Position: 'maschenbautechniker' → Predicted: 'Junior'
#   Position: 'java software engeer' → Predicted: 'Senior'
#   Position: 'projektmanager' → Predicted: 'Junior'
#   Position: 'brand ambassador' → Predicted: 'Junior'
#   Position: 'projektmanager' → Predicted: 'Junior'
#   Position: 'project engeer process technology future farmg' → Predicted: 'Senior'
#   Position: 'dan manl k' → Predicted: 'Junior'
#   Position: 'digital marketg manager' → Predicted: 'Senior'
#   Position: 'theatermaker' → Predicted: 'Junior'
#   Position: 'traer coach' → Predicted: 'Senior'
#   Position: 'tragsacteur en traer' → Predicted: 'Junior'
#   Position: 'co traer tragsacteur' → Predicted: 'Management'
#   Position: 'acteur en theatermaker' → Predicted: 'Junior'
#   Position: 'traer docent' → Predicted: 'Junior'
#   Position: 'freelance acteur regisseur en scriptschrijver' → Predicted: 'Junior'
#   Position: 'procurement manager strategische koop' → Predicted: 'Senior'
#   Position: 'strategisch koper' → Predicted: 'Junior'
#   Position: 'side sales' → Predicted: 'Junior'
#   Position: 'key account manager' → Predicted: 'Senior'
#   Position: 'berufskraftfahrer' → Predicted: 'Junior'
#   Position: 'key account manager' → Predicted: 'Senior'
#   Position: 'project manager' → Predicted: 'Senior'
#   Position: 'management consultant formation security and privacy' → Predicted: 'Junior'
#   Position: 'departementssekretaer fanz' → Predicted: 'Junior'
#   Position: 'manager mergers acquisitions' → Predicted: 'Senior'
#   Position: 'account manager s lger helly hansen workwear sj lland bornholm' → Predicted: 'Senior'
#   Position: 'fance aws global private pricg' → Predicted: 'Junior'
#   Position: 'software developer' → Predicted: 'Junior'
#   Position: 'summer camp counselor' → Predicted: 'Junior'
#   Position: 'rechtsanwalt' → Predicted: 'Junior'
#   Position: 'writer editor publisher' → Predicted: 'Junior'
#   Position: 'klavierlehrer korrepetitor' → Predicted: 'Junior'
#   Position: 'manager' → Predicted: 'Senior'
#   Position: 'robotertechniker' → Predicted: 'Junior'
#   Position: 'sachbearbeiter der beschlagwortung rueckpost' → Predicted: 'Junior'
#   Position: 'scierie collignon' → Predicted: 'Junior'
#   Position: 'product manager onle catalog shop' → Predicted: 'Senior'
#   Position: 'diplom baugenieur' → Predicted: 'Junior'
#   Position: 'physiotherapeut' → Predicted: 'Junior'
#   Position: 'software developer' → Predicted: 'Junior'
#   Position: 'self employed at kodestuen aps' → Predicted: 'Junior'
#   Position: 'dozent ausbilder' → Predicted: 'Junior'
#   Position: 'busess consultant' → Predicted: 'Junior'
#   Position: 'citrix systems engeer' → Predicted: 'Senior'
#   Position: 'anesthesiemedewerker' → Predicted: 'Junior'
#   Position: 'impulsgeber bei kaiserschote gmbh' → Predicted: 'Junior'
#   Position: 'gerente de comunica o e marketg' → Predicted: 'Junior'
#   Position: 'formation technology busess analyst' → Predicted: 'Junior'
#   Position: 'private equity vestments' → Predicted: 'Junior'
#   Position: 'devops orchestration manager' → Predicted: 'Senior'
#   Position: 'kfz mechatroniker' → Predicted: 'Junior'
#   Position: 'grafik designer' → Predicted: 'Junior'
#   Position: 'manager regional key accounts americas' → Predicted: 'Senior'
#   Position: 'digital project manager marketg' → Predicted: 'Senior'
#   Position: 'mediaberater dps fachzeitschrift f schaedlgsbekaempfung salesmanager dps pest control magaze' → Predicted: 'Junior'
#   Position: 'data analyst' → Predicted: 'Junior'
#   Position: 'professor' → Predicted: 'Junior'
#   Position: 'neutraublg' → Predicted: 'Junior'
#   Position: 'data analyst sustaable fund fance' → Predicted: 'Junior'
#   Position: 'kundansvarig' → Predicted: 'Junior'
#   Position: 'verwaltungsangestellter' → Predicted: 'Junior'
#   Position: 'global it solution architect supply cha transportation' → Predicted: 'Senior'
#   Position: 'sourcg specialist' → Predicted: 'Junior'
#   Position: 'marketplace manager onle shop manager' → Predicted: 'Senior'
#   Position: 'account manager' → Predicted: 'Senior'
#   Position: 'account manager' → Predicted: 'Senior'
#   Position: 'group design strategy targets' → Predicted: 'Junior'
#   Position: 'werteorientiertes fuehrungskraeftetrag' → Predicted: 'Junior'
#   Position: 'vertrieb' → Predicted: 'Junior'
#   Position: 'hr manager' → Predicted: 'Senior'
#   Position: 'konstrukteur' → Predicted: 'Junior'
#   Position: 'sales marketg management' → Predicted: 'Senior'
#   Position: 'retail marketg management' → Predicted: 'Senior'
#   Position: 'ruby fullstack developer' → Predicted: 'Junior'
#   Position: 'fancial analyst' → Predicted: 'Junior'
#   Position: 'vertriebsgenieur' → Predicted: 'Junior'
#   Position: 'professor im ruhestand' → Predicted: 'Junior'
#   Position: 'key account manager' → Predicted: 'Senior'
#   Position: 'selbststaendig' → Predicted: 'Junior'
#   Position: 'project manager' → Predicted: 'Senior'
#   Position: 'enseignant' → Predicted: 'Junior'
#   Position: 'rechtsanwalt' → Predicted: 'Junior'
#   Position: 'rechtsanwalt' → Predicted: 'Junior'
#   Position: 'commercial service manager' → Predicted: 'Senior'
#   Position: 'quality manager' → Predicted: 'Senior'
#   Position: 'human resources specialist' → Predicted: 'Junior'
#   Position: '49504' → Predicted: 'Junior'
#   Position: 'family nurse practitioner' → Predicted: 'Junior'
#   Position: 'erichtungsberater' → Predicted: 'Junior'
#   Position: 'sap solutions consultant' → Predicted: 'Junior'
#   Position: 'freelance marketg consultg client service terim marketg brandg' → Predicted: 'Senior'
#   Position: 'progettista fanza agevolata research fundg admistration' → Predicted: 'Junior'
#   Position: 'chief researcher' → Predicted: 'Junior'
#   Position: 'application consultant' → Predicted: 'Junior'
#   Position: 'postdoctoral researcher and lecturer' → Predicted: 'Junior'
#   Position: 'purchasg manager' → Predicted: 'Senior'
#   Position: 'postdoctoral research fellow' → Predicted: 'Junior'
#   Position: 'strategic purchasg manager group purchasg' → Predicted: 'Senior'
#   Position: 'konsult hr' → Predicted: 'Junior'
#   Position: 'produktmanager optomechanik' → Predicted: 'Junior'
#   Position: 'clical physicist' → Predicted: 'Junior'
#   Position: 'researcher' → Predicted: 'Junior'
#   Position: 'apl professor adjunct professor' → Predicted: 'Junior'
#   Position: 'arbeitslos' → Predicted: 'Junior'
#   Position: 'master data demand manager supply cha management' → Predicted: 'Senior'
#   Position: 'platform support direct drive' → Predicted: 'Junior'
#   Position: 'recruitment manager' → Predicted: 'Senior'
#   Position: 'professor' → Predicted: 'Junior'
#   Position: 'automaticien electricien' → Predicted: 'Junior'
#   Position: 'grafikdesigner freelance' → Predicted: 'Junior'
#   Position: 'matenance engeerg manager' → Predicted: 'Senior'
#   Position: 'researcher' → Predicted: 'Junior'
#   Position: 'cloud advisory analyst' → Predicted: 'Junior'
#   Position: 'research development group manager' → Predicted: 'Senior'
#   Position: 'jurist' → Predicted: 'Junior'
#   Position: 'hgf' → Predicted: 'Junior'
#   Position: 'quality engeer' → Predicted: 'Junior'
#   Position: 'vakbekwaam hovenier' → Predicted: 'Junior'
#   Position: 'verkaufsmanager' → Predicted: 'Junior'
#   Position: 'professor of french and francophone studies' → Predicted: 'Junior'
#   Position: 'hr specialist personnel development' → Predicted: 'Junior'
#   Position: 'fance and hr' → Predicted: 'Junior'
#   Position: 'dozent' → Predicted: 'Junior'
#   Position: 'avp dental quality clical oversight' → Predicted: 'Junior'
#   Position: 'special education advocate education consultant' → Predicted: 'Junior'
#   Position: 'systemischer berater fuer organisationsentwicklung und coach' → Predicted: 'Junior'
#   Position: 'hr it consultant' → Predicted: 'Junior'
#   Position: 'bestuursassistent' → Predicted: 'Junior'
#   Position: 'utbildare och konsult om organisation ledarskap och projektledng' → Predicted: 'Junior'
#   Position: 'member' → Predicted: 'Junior'
#   Position: 'buyer' → Predicted: 'Junior'
#   Position: 'warranty service specialist' → Predicted: 'Junior'
#   Position: 'hr talent manager' → Predicted: 'Senior'
#   Position: 'freelance photographer' → Predicted: 'Junior'
#   Position: 'addetto alla logistica' → Predicted: 'Junior'
#   Position: 'office admistrator' → Predicted: 'Junior'
#   Position: 'portfolio manager' → Predicted: 'Senior'
#   Position: 'technical development manager terconnect' → Predicted: 'Senior'
#   Position: 'dipl baugenieur fh stv' → Predicted: 'Junior'
#   Position: 'programmierer' → Predicted: 'Junior'
#   Position: 'global mobility consultant' → Predicted: 'Senior'
#   Position: 'facharzt fuer orthopaedie und unfallchirurgie chirurgie chirotherapie naturheilverfahren' → Predicted: 'Junior'
#   Position: 'daytrader' → Predicted: 'Junior'
#   Position: 'equipment project manager' → Predicted: 'Senior'
#   Position: 'lian da formation technology co ltd' → Predicted: 'Junior'
#   Position: 'evp strategic partnerships' → Predicted: 'Junior'
#   Position: 'bauverwaltung' → Predicted: 'Junior'
#   Position: 'baubeamter' → Predicted: 'Junior'
#   Position: 'rechtsanwalt mit schwerpunkt gen biotechnik und arzneimittelrecht' → Predicted: 'Junior'
#   Position: 'sports columnist' → Predicted: 'Junior'
#   Position: 'managg consultant busess transformation' → Predicted: 'Junior'
#   Position: 'kgmaker' → Predicted: 'Junior'
#   Position: 'member' → Predicted: 'Junior'
#   Position: 'member' → Predicted: 'Junior'
#   Position: 'member' → Predicted: 'Junior'
#   Position: 'public health consultant' → Predicted: 'Junior'
#   Position: 'projektmanager therapieberufe' → Predicted: 'Junior'
#   Position: 'qualitaetsicherung' → Predicted: 'Junior'
#   Position: 'referent digitale schiene' → Predicted: 'Junior'
#   Position: 'diatary aide' → Predicted: 'Junior'
#   Position: 'consultant' → Predicted: 'Senior'
#   Position: 'research analyst' → Predicted: 'Junior'
#   Position: 'product and service manager qualitymanagement solution architect' → Predicted: 'Senior'
#   Position: 'elektrotechniker mit erweitertem aufgabenbereich' → Predicted: 'Junior'
#   Position: 'regional sales manager central european region' → Predicted: 'Senior'
#   Position: 'key account manager' → Predicted: 'Senior'
#   Position: 'non compete phase' → Predicted: 'Junior'
#   Position: 'branch manager' → Predicted: 'Senior'
#   Position: 'summoner' → Predicted: 'Junior'
#   Position: 'busess development agent' → Predicted: 'Junior'
#   Position: 'advisor' → Predicted: 'Junior'
#   Position: 'advisor' → Predicted: 'Junior'
#   Position: 'exo traer' → Predicted: 'Junior'
#   Position: 'ambassador' → Predicted: 'Junior'
#   Position: 'exo consultant' → Predicted: 'Senior'
#   Position: 'member' → Predicted: 'Junior'
#   Position: 'multiplicador b' → Predicted: 'Junior'
#   Position: 'professeur de math matique particulier' → Predicted: 'Junior'
#   Position: 'automotive sales manager' → Predicted: 'Senior'
#   Position: 'personal traer' → Predicted: 'Junior'
#   Position: 'cultivation' → Predicted: 'Junior'
#   Position: 'pensionaer' → Predicted: 'Junior'
#   Position: 'supply cha manager' → Predicted: 'Senior'
#   Position: 'transport manager' → Predicted: 'Senior'
#   Position: 'softwareentwickler' → Predicted: 'Junior'
#   Position: 'radio engeerg tdi huawei sran mobile network testg' → Predicted: 'Junior'
#   Position: 'site manager' → Predicted: 'Senior'
#   Position: 'buyg porecurement allocation' → Predicted: 'Junior'
#   Position: 'justitiar' → Predicted: 'Junior'
#   Position: 'rechtsanwalt' → Predicted: 'Junior'
#
# Label 'Lead' was incorrectly predicted 119 times:
#   Position: 'gerente comercial' → Predicted: 'Junior'
#   Position: 'apl ansvarig samordng' → Predicted: 'Junior'
#   Position: 'lab supervisor' → Predicted: 'Junior'
#   Position: 'bereichsleiter maschen' → Predicted: 'Junior'
#   Position: 'it teamleiter' → Predicted: 'Junior'
#   Position: 'head of hr chro' → Predicted: 'Senior'
#   Position: 'sub stream lead simplify turnaround programs' → Predicted: 'Junior'
#   Position: 'projektleiter bildung' → Predicted: 'Junior'
#   Position: 'practice leader data valorization strategy' → Predicted: 'Junior'
#   Position: 'technical team lead' → Predicted: 'Junior'
#   Position: 'technical customer service manager flexible packagg' → Predicted: 'Senior'
#   Position: 'new busess manager' → Predicted: 'Senior'
#   Position: 'strategic engagement manager' → Predicted: 'Senior'
#   Position: 'head of aws preseed and seedfancg novative solutions' → Predicted: 'Senior'
#   Position: 'lead naval architect' → Predicted: 'Junior'
#   Position: 'head of glass technology' → Predicted: 'Senior'
#   Position: 'accountg manager' → Predicted: 'Senior'
#   Position: 'terims technical manager' → Predicted: 'Senior'
#   Position: 'bueroleiter pressesprecher' → Predicted: 'Junior'
#   Position: 'lehrbeauftragter' → Predicted: 'Junior'
#   Position: 'technical transfer leader' → Predicted: 'Junior'
#   Position: 'ceo morgenpost tag 24 vertriebsleiter saechsische zeitung lesermark ceo mvd oekoflitzer' → Predicted: 'Management'
#   Position: 'key account supply manager' → Predicted: 'Senior'
#   Position: 'projektleiter qualitaet hv batterie' → Predicted: 'Junior'
#   Position: 'project lead for swap re engeerg project' → Predicted: 'Junior'
#   Position: 'head of accountg controllg' → Predicted: 'Senior'
#   Position: 'personalleiter' → Predicted: 'Junior'
#   Position: 'head of engeerg' → Predicted: 'Senior'
#   Position: 'district sales manager' → Predicted: 'Senior'
#   Position: 'ooe koordator fuer das team der bereiche beschlagwortung zustellproblem' → Predicted: 'Junior'
#   Position: 'head of content workflows' → Predicted: 'Senior'
#   Position: 'head of busess consultg content digital assets' → Predicted: 'Senior'
#   Position: 'leiter controllg und rechnungswesen' → Predicted: 'Junior'
#   Position: 'architekt fachgebietsleitung technisches und strategisches gebaeudemanagement' → Predicted: 'Junior'
#   Position: 'co head of bid management ce' → Predicted: 'Senior'
#   Position: 'bid manager' → Predicted: 'Senior'
#   Position: 'leiter it service und betriebsmanagement' → Predicted: 'Junior'
#   Position: 'betriebsleiter' → Predicted: 'Junior'
#   Position: 'projektkoordator' → Predicted: 'Junior'
#   Position: 'regionalbeauftragter club sachsen thuergen sachsen anhalt sued' → Predicted: 'Junior'
#   Position: 'hoofd bouwbureau' → Predicted: 'Junior'
#   Position: 'head of package stallation design igc' → Predicted: 'Senior'
#   Position: 'station manager at ground2air palma de mallorca' → Predicted: 'Senior'
#   Position: 'bereichs pdl' → Predicted: 'Junior'
#   Position: 'senior project leader' → Predicted: 'Senior'
#   Position: 'teamleder arkitektur drift og sikkerhet it seksjonen vid' → Predicted: 'Junior'
#   Position: 'responsable technique' → Predicted: 'Senior'
#   Position: 'head of group capital markets' → Predicted: 'Senior'
#   Position: 'regionalleiter bankenbetreuung baden wuerttemberg' → Predicted: 'Junior'
#   Position: 'projektleder' → Predicted: 'Junior'
#   Position: 'supply cha lead master planng' → Predicted: 'Junior'
#   Position: 'head of startup engagements for s 4hana and digital supply cha' → Predicted: 'Senior'
#   Position: 'head of marketg promotg label free cell analysis technology' → Predicted: 'Senior'
#   Position: 'head of logistics' → Predicted: 'Senior'
#   Position: 'referatsleiter' → Predicted: 'Junior'
#   Position: 'bueroleiter' → Predicted: 'Junior'
#   Position: 'ppa head of treasury surance' → Predicted: 'Senior'
#   Position: 'teamleiter disposition fahrzeuge und stv ressourcenplaner' → Predicted: 'Junior'
#   Position: 'head of marketg communications emea oxford struments group' → Predicted: 'Senior'
#   Position: 'assistant manager' → Predicted: 'Senior'
#   Position: 'lead consultant' → Predicted: 'Senior'
#   Position: 'head of it services operations management' → Predicted: 'Senior'
#   Position: 'teamleader it operations management' → Predicted: 'Senior'
#   Position: 'operation supervisor' → Predicted: 'Junior'
#   Position: 'projektleiter der engeerg it' → Predicted: 'Junior'
#   Position: 'country manager czech republic and slovakia' → Predicted: 'Senior'
#   Position: 'head of account management' → Predicted: 'Senior'
#   Position: 'bergungsleiter' → Predicted: 'Junior'
#   Position: 'head of regulatory projects' → Predicted: 'Senior'
#   Position: 'vedouc pobo ky pop vky' → Predicted: 'Junior'
#   Position: 'lead engeer groepscoordator' → Predicted: 'Senior'
#   Position: 'dezernat fuer wirtschaft stadtentwicklung liegenschaften und ordnungswesen bueroleitung referent' → Predicted: 'Junior'
#   Position: 'projektleiter' → Predicted: 'Junior'
#   Position: 'teamleitung ersatzteile' → Predicted: 'Junior'
#   Position: 'head of capex delivery management and planng site leverkusen' → Predicted: 'Senior'
#   Position: 'geschaeftsleiter' → Predicted: 'Junior'
#   Position: 'betriebsleiter api produktion' → Predicted: 'Junior'
#   Position: 'global chief engeer manager power electronics obc dcdc' → Predicted: 'Senior'
#   Position: 'head of mechanical engiuneerg' → Predicted: 'Senior'
#   Position: 'communications coordator' → Predicted: 'Junior'
#   Position: 'head of ict' → Predicted: 'Senior'
#   Position: 'responsable' → Predicted: 'Senior'
#   Position: 'head of sales dach' → Predicted: 'Senior'
#   Position: 'verkaufsleitung' → Predicted: 'Junior'
#   Position: 'head of marketg technology teamlead' → Predicted: 'Senior'
#   Position: 'account manager talent acquisition lead' → Predicted: 'Senior'
#   Position: 'bereichsleiter central service center' → Predicted: 'Junior'
#   Position: 'schornstefeger meisterbetrieb' → Predicted: 'Junior'
#   Position: 'leiter managed it cloud services' → Predicted: 'Junior'
#   Position: 'head of accountg and tax department' → Predicted: 'Senior'
#   Position: 'teamleiter bestandesentwicklung' → Predicted: 'Junior'
#   Position: 'projektleiter bestandesentwicklung bei liegenschaften stadt zuerich' → Predicted: 'Junior'
#   Position: 'projektleiter' → Predicted: 'Junior'
#   Position: 'head of procurement' → Predicted: 'Senior'
#   Position: 'assistent der geschaeftsleitung' → Predicted: 'Junior'
#   Position: 'sub manager coordation planng' → Predicted: 'Senior'
#   Position: 'sub manager coordation planng' → Predicted: 'Senior'
#   Position: 'gesamtleiter personal mitglied der geschaeftsleitung' → Predicted: 'Junior'
#   Position: 'responsable de salle' → Predicted: 'Senior'
#   Position: 'project coordator fance' → Predicted: 'Junior'
#   Position: 'bauprojektleiter' → Predicted: 'Junior'
#   Position: 'projektleiter bau neubauprojekte' → Predicted: 'Junior'
#   Position: 'key account project manager' → Predicted: 'Senior'
#   Position: 'abteilungsleiter vertrieb dipl bankbetriebswirt management adg' → Predicted: 'Senior'
#   Position: 'tekniklektor' → Predicted: 'Junior'
#   Position: 'head of busess unit fance executive vice president' → Predicted: 'Management'
#   Position: 'facility coordator cbre gws gmbh' → Predicted: 'Junior'
#   Position: 'facility coordator' → Predicted: 'Junior'
#   Position: 'regionaler vertriebsleiter' → Predicted: 'Junior'
#   Position: 'qualitaetsmanager' → Predicted: 'Junior'
#   Position: 'qualitaetsmanager' → Predicted: 'Junior'
#   Position: 'head of sales partnerships' → Predicted: 'Senior'
#   Position: 'vertriebsleiter' → Predicted: 'Junior'
#   Position: 'devsecops coe lead' → Predicted: 'Junior'
#   Position: 'head of riv academy blockcha' → Predicted: 'Senior'
#   Position: 'team bereichsleiter' → Predicted: 'Junior'
#   Position: 'exo sprt coach' → Predicted: 'Senior'
#   Position: 'busess development leader' → Predicted: 'Junior'
#   Position: 'digitalbeauftragte' → Predicted: 'Junior'
#
# Label 'Director' was incorrectly predicted 11 times:
#   Position: 'global director head of portfolio and busess development global service' → Predicted: 'Senior'
#   Position: 'assistant director of prospect management and data analytics' → Predicted: 'Senior'
#   Position: 'director general sector and global programmes' → Predicted: 'Senior'
#   Position: 'landesdirektor' → Predicted: 'Junior'
#   Position: 'vertriebsdirektor' → Predicted: 'Junior'
#   Position: 'directeur de la construction' → Predicted: 'Junior'
#   Position: 'directeur projet' → Predicted: 'Junior'
#   Position: 'abteilungsdirektor vertrieb' → Predicted: 'Junior'
#   Position: 'directeur' → Predicted: 'Junior'
#   Position: 'key account director europe middle east africa' → Predicted: 'Senior'
#   Position: 'key account director europe middle east africa' → Predicted: 'Senior'
#
# Label 'Senior' was incorrectly predicted 6 times:
#   Position: 'technischer experte fuer stellwerkstechnik' → Predicted: 'Junior'
#   Position: 'aircraft physical security expert' → Predicted: 'Junior'
#   Position: 'mentor' → Predicted: 'Junior'
#   Position: 'managg sr underwritg director' → Predicted: 'Director'
#   Position: 'prcipal' → Predicted: 'Junior'
#   Position: 'advanced purchasg commercial vehicles and services' → Predicted: 'Junior'
#
# Department Error Analysis
#
# Label 'Other' was incorrectly predicted 126 times:
#   Position: 'prokurist' → Predicted: 'Marketing'
#   Position: 'prokurist' → Predicted: 'Marketing'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'geschaeftsfuehrender gesellschafter' → Predicted: 'Human Resources'
#   Position: 'co owner' → Predicted: 'Marketing'
#   Position: 'ceo' → Predicted: 'Administrative'
#   Position: 'ceo founder' → Predicted: 'Administrative'
#   Position: 'director' → Predicted: 'Marketing'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'ceo managg shareholder' → Predicted: 'Administrative'
#   Position: 'co owner' → Predicted: 'Marketing'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'head of aws preseed and seedfancg novative solutions' → Predicted: 'Marketing'
#   Position: 'executive director of therapies and developmental services' → Predicted: 'Marketing'
#   Position: 'co traer tragsacteur' → Predicted: 'Marketing'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'head of glass technology' → Predicted: 'Marketing'
#   Position: 'accountg manager' → Predicted: 'Marketing'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'manager mergers acquisitions' → Predicted: 'Marketing'
#   Position: 'geschaeftsfuehrender gesellschafter' → Predicted: 'Human Resources'
#   Position: 'director' → Predicted: 'Marketing'
#   Position: 'unternehmenshaber' → Predicted: 'Customer Support'
#   Position: 'ceo' → Predicted: 'Administrative'
#   Position: 'fance aws global private pricg' → Predicted: 'Marketing'
#   Position: 'ceo morgenpost tag 24 vertriebsleiter saechsische zeitung lesermark ceo mvd oekoflitzer' → Predicted: 'Administrative'
#   Position: 'key account supply manager' → Predicted: 'Marketing'
#   Position: 'styreleder partner' → Predicted: 'Business Development'
#   Position: 'kaufmaennische leiter' → Predicted: 'Marketing'
#   Position: 'head of accountg controllg' → Predicted: 'Marketing'
#   Position: 'assistant director of prospect management and data analytics' → Predicted: 'Marketing'
#   Position: 'managg partner group managg board' → Predicted: 'Business Development'
#   Position: 'manager' → Predicted: 'Marketing'
#   Position: 'managg dircector' → Predicted: 'Marketing'
#   Position: 'head of busess consultg content digital assets' → Predicted: 'Marketing'
#   Position: 'product manager onle catalog shop' → Predicted: 'Project Management'
#   Position: 'leiter controllg und rechnungswesen' → Predicted: 'Marketing'
#   Position: 'co ceo' → Predicted: 'Administrative'
#   Position: 'senior legal advisor' → Predicted: 'Marketing'
#   Position: 'geschaeftsfuehrender gesellschafter' → Predicted: 'Human Resources'
#   Position: 'fance director central europe' → Predicted: 'Marketing'
#   Position: 'senior program analyst immigration' → Predicted: 'Marketing'
#   Position: 'director general sector and global programmes' → Predicted: 'Marketing'
#   Position: 'station manager at ground2air palma de mallorca' → Predicted: 'Marketing'
#   Position: 'geschaeftsfuehrender gesellschafter' → Predicted: 'Human Resources'
#   Position: 'geschaeftsfuehrender gesellschafter' → Predicted: 'Human Resources'
#   Position: 'geschaeftsfuehrender gesellschafter' → Predicted: 'Human Resources'
#   Position: 'head of group capital markets' → Predicted: 'Marketing'
#   Position: 'ceo' → Predicted: 'Administrative'
#   Position: 'geschaeftsfuehrender gesellschafter' → Predicted: 'Human Resources'
#   Position: 'ceo' → Predicted: 'Administrative'
#   Position: 'ceo' → Predicted: 'Administrative'
#   Position: 'executive director' → Predicted: 'Administrative'
#   Position: 'supply cha lead master planng' → Predicted: 'Marketing'
#   Position: 'global vp and head of sustaability novation' → Predicted: 'Marketing'
#   Position: 'head of logistics' → Predicted: 'Marketing'
#   Position: 'kfm prokurist' → Predicted: 'Marketing'
#   Position: 'foundg partner' → Predicted: 'Business Development'
#   Position: 'directeur de la construction' → Predicted: 'Marketing'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'ppa head of treasury surance' → Predicted: 'Marketing'
#   Position: 'vorsitzender des vorstandes ceo' → Predicted: 'Administrative'
#   Position: 'unternehmenshaber' → Predicted: 'Customer Support'
#   Position: 'unternehmenshaber' → Predicted: 'Customer Support'
#   Position: 'unternehmenshaber' → Predicted: 'Customer Support'
#   Position: 'director openvalue amsterdam' → Predicted: 'Marketing'
#   Position: 'group design strategy targets' → Predicted: 'Marketing'
#   Position: 'ceo' → Predicted: 'Administrative'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'assistant manager' → Predicted: 'Marketing'
#   Position: 'senior audit associate' → Predicted: 'Marketing'
#   Position: 'geschaeftsfuehrender gesellschafter' → Predicted: 'Human Resources'
#   Position: 'sales marketg management' → Predicted: 'Marketing'
#   Position: 'ceo' → Predicted: 'Administrative'
#   Position: 'country manager czech republic and slovakia' → Predicted: 'Marketing'
#   Position: 'executive director at adform s r o' → Predicted: 'Administrative'
#   Position: 'group ceo' → Predicted: 'Administrative'
#   Position: 'director fance and formation technology' → Predicted: 'Marketing'
#   Position: 'co ceo' → Predicted: 'Administrative'
#   Position: 'general manager' → Predicted: 'Marketing'
#   Position: 'dezernat fuer wirtschaft stadtentwicklung liegenschaften und ordnungswesen bueroleitung referent' → Predicted: 'Marketing'
#   Position: 'general manager' → Predicted: 'Marketing'
#   Position: 'quality manager' → Predicted: 'Marketing'
#   Position: 'unternehmenshaber' → Predicted: 'Customer Support'
#   Position: 'unternehmenshaber' → Predicted: 'Customer Support'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'senior treasury manager' → Predicted: 'Marketing'
#   Position: 'head of mechanical engiuneerg' → Predicted: 'Marketing'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'responsable' → Predicted: 'Marketing'
#   Position: 'ceo krueger kommunikasjon as' → Predicted: 'Administrative'
#   Position: 'senior lecturer education focused' → Predicted: 'Marketing'
#   Position: 'master data demand manager supply cha management' → Predicted: 'Marketing'
#   Position: 'general manager' → Predicted: 'Marketing'
#   Position: 'geschaeftsfuehrender gesellschafter' → Predicted: 'Human Resources'
#   Position: 'geschaeftsfuehrender gesellschafter ceo' → Predicted: 'Human Resources'
#   Position: 'head of accountg and tax department' → Predicted: 'Marketing'
#   Position: 'managg director co founder' → Predicted: 'Marketing'
#   Position: 'senior manager' → Predicted: 'Marketing'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'co founder and ceo' → Predicted: 'Administrative'
#   Position: 'co executive director' → Predicted: 'Administrative'
#   Position: 'ceo co founder' → Predicted: 'Administrative'
#   Position: 'general manager vice president of planng' → Predicted: 'Marketing'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'key account project manager' → Predicted: 'Marketing'
#   Position: 'ceo' → Predicted: 'Administrative'
#   Position: 'managg director' → Predicted: 'Marketing'
#   Position: 'director of food and beverage' → Predicted: 'Marketing'
#   Position: 'managg sr underwritg director' → Predicted: 'Marketing'
#   Position: 'director' → Predicted: 'Marketing'
#   Position: 'ceo' → Predicted: 'Administrative'
#   Position: 'portfolio manager' → Predicted: 'Marketing'
#   Position: 'ceo' → Predicted: 'Administrative'
#   Position: 'senior manager' → Predicted: 'Marketing'
#   Position: 'senior hvac technician' → Predicted: 'Marketing'
#   Position: 'ceo' → Predicted: 'Administrative'
#   Position: 'senior fancial crimes vestigator' → Predicted: 'Marketing'
#   Position: 'leiter zerstoerungsfreie pruefungen mqp' → Predicted: 'Marketing'
#   Position: 'geschaeftsfuehrer general manager' → Predicted: 'Marketing'
#   Position: 'product and service manager qualitymanagement solution architect' → Predicted: 'Marketing'
#   Position: 'geschaeftsfuehrender haber' → Predicted: 'Human Resources'
#   Position: 'general manager' → Predicted: 'Marketing'
#   Position: 'branch manager' → Predicted: 'Marketing'
#   Position: 'supply cha manager' → Predicted: 'Marketing'
#   Position: 'transport manager' → Predicted: 'Marketing'
#
# Label 'Information Technology' was incorrectly predicted 62 times:
#   Position: 'solutions architect' → Predicted: 'Marketing'
#   Position: 'prcipal rf design engeer' → Predicted: 'Marketing'
#   Position: 'it systems and network engeer' → Predicted: 'Other'
#   Position: 'it teamleiter' → Predicted: 'Other'
#   Position: 'senior it sicherheitsbeauftragter' → Predicted: 'Marketing'
#   Position: 'it systemadmistrator' → Predicted: 'Other'
#   Position: 'technical team lead' → Predicted: 'Marketing'
#   Position: 'java software engeer' → Predicted: 'Marketing'
#   Position: 'project engeer process technology future farmg' → Predicted: 'Marketing'
#   Position: 'terims technical manager' → Predicted: 'Marketing'
#   Position: 'software developer' → Predicted: 'Marketing'
#   Position: 'head of engeerg' → Predicted: 'Marketing'
#   Position: 'director of busess analysts and special projects' → Predicted: 'Marketing'
#   Position: 'robotertechniker' → Predicted: 'Other'
#   Position: 'senior microsoft 365 engeer' → Predicted: 'Marketing'
#   Position: 'leiter it service und betriebsmanagement' → Predicted: 'Marketing'
#   Position: 'software developer' → Predicted: 'Marketing'
#   Position: 'cto' → Predicted: 'Other'
#   Position: 'teamleder arkitektur drift og sikkerhet it seksjonen vid' → Predicted: 'Other'
#   Position: 'responsable technique' → Predicted: 'Marketing'
#   Position: 'citrix systems engeer' → Predicted: 'Other'
#   Position: 'formation technology busess analyst' → Predicted: 'Other'
#   Position: 'devops orchestration manager' → Predicted: 'Marketing'
#   Position: 'chief technology officer' → Predicted: 'Other'
#   Position: 'data analyst' → Predicted: 'Other'
#   Position: 'global it solution architect supply cha transportation' → Predicted: 'Marketing'
#   Position: 'director code nomads amsterdam' → Predicted: 'Marketing'
#   Position: 'cto' → Predicted: 'Other'
#   Position: 'head of it services operations management' → Predicted: 'Marketing'
#   Position: 'teamleader it operations management' → Predicted: 'Marketing'
#   Position: 'technischer experte fuer stellwerkstechnik' → Predicted: 'Other'
#   Position: 'projektleiter der engeerg it' → Predicted: 'Marketing'
#   Position: 'ruby fullstack developer' → Predicted: 'Marketing'
#   Position: 'lead engeer groepscoordator' → Predicted: 'Marketing'
#   Position: 'senior enterprise it systems specialist' → Predicted: 'Marketing'
#   Position: 'senior it lizenzspezialist' → Predicted: 'Marketing'
#   Position: 'betriebsleiter api produktion' → Predicted: 'Other'
#   Position: 'global chief engeer manager power electronics obc dcdc' → Predicted: 'Marketing'
#   Position: 'senior manager product development' → Predicted: 'Marketing'
#   Position: 'software engeer iv' → Predicted: 'Marketing'
#   Position: 'head of ict' → Predicted: 'Marketing'
#   Position: 'chief researcher' → Predicted: 'Other'
#   Position: 'matenance engeerg manager' → Predicted: 'Marketing'
#   Position: 'senior ux designer' → Predicted: 'Marketing'
#   Position: 'leiter managed it cloud services' → Predicted: 'Marketing'
#   Position: 'research development group manager' → Predicted: 'Marketing'
#   Position: 'aegare affaersomr deschef it cto' → Predicted: 'Other'
#   Position: 'managg director cto' → Predicted: 'Marketing'
#   Position: 'quality engeer' → Predicted: 'Project Management'
#   Position: 'cyber security analyst senior' → Predicted: 'Marketing'
#   Position: 'executive vice president connected software systems services' → Predicted: 'Other'
#   Position: 'senior data analyst' → Predicted: 'Marketing'
#   Position: 'tekniklektor' → Predicted: 'Other'
#   Position: 'senior technology architect' → Predicted: 'Marketing'
#   Position: 'technical development manager terconnect' → Predicted: 'Marketing'
#   Position: 'programmierer' → Predicted: 'Other'
#   Position: 'devsecops coe lead' → Predicted: 'Other'
#   Position: 'qualitaetsicherung' → Predicted: 'Other'
#   Position: 'head of riv academy blockcha' → Predicted: 'Marketing'
#   Position: 'software architect' → Predicted: 'Marketing'
#   Position: 'softwareentwickler' → Predicted: 'Other'
#   Position: 'radio engeerg tdi huawei sran mobile network testg' → Predicted: 'Marketing'
#
# Label 'Consulting' was incorrectly predicted 39 times:
#   Position: 'mediztechnik beratung' → Predicted: 'Other'
#   Position: 'energy and sustaability consultant bei' → Predicted: 'Other'
#   Position: 'human resources consultant' → Predicted: 'Marketing'
#   Position: 'practice leader data valorization strategy' → Predicted: 'Other'
#   Position: 'dan manl k' → Predicted: 'Other'
#   Position: 'tragsacteur en traer' → Predicted: 'Other'
#   Position: 'management consultant formation security and privacy' → Predicted: 'Other'
#   Position: 'senior manager strategy busess transformation health' → Predicted: 'Marketing'
#   Position: 'lehrbeauftragter' → Predicted: 'Other'
#   Position: 'technical transfer leader' → Predicted: 'Other'
#   Position: 'founder and senior partner' → Predicted: 'Other'
#   Position: 'senior human resources consultant' → Predicted: 'Marketing'
#   Position: 'research associate' → Predicted: 'Other'
#   Position: 'busess consultant' → Predicted: 'Business Development'
#   Position: 'senior managg consultant' → Predicted: 'Marketing'
#   Position: 'entrepreneur general et consultat construction' → Predicted: 'Marketing'
#   Position: 'lead consultant' → Predicted: 'Business Development'
#   Position: 'werteorientiertes fuehrungskraeftetrag' → Predicted: 'Other'
#   Position: 'head of regulatory projects' → Predicted: 'Marketing'
#   Position: 'senior consultant procurement excellence' → Predicted: 'Marketing'
#   Position: 'sap solutions consultant' → Predicted: 'Business Development'
#   Position: 'senior consultant' → Predicted: 'Marketing'
#   Position: 'freelance marketg consultg client service terim marketg brandg' → Predicted: 'Marketing'
#   Position: 'application consultant' → Predicted: 'Business Development'
#   Position: 'cloud advisory analyst' → Predicted: 'Other'
#   Position: 'special education advocate education consultant' → Predicted: 'Marketing'
#   Position: 'systemischer berater fuer organisationsentwicklung und coach' → Predicted: 'Marketing'
#   Position: 'hr it consultant' → Predicted: 'Business Development'
#   Position: 'utbildare och konsult om organisation ledarskap och projektledng' → Predicted: 'Other'
#   Position: 'global mobility consultant' → Predicted: 'Marketing'
#   Position: 'managg consultant busess transformation' → Predicted: 'Business Development'
#   Position: 'public health consultant' → Predicted: 'Other'
#   Position: 'consultant' → Predicted: 'Business Development'
#   Position: 'senior consultant data center' → Predicted: 'Marketing'
#   Position: 'advisor' → Predicted: 'Marketing'
#   Position: 'advisor' → Predicted: 'Marketing'
#   Position: 'exo sprt coach' → Predicted: 'Marketing'
#   Position: 'exo consultant' → Predicted: 'Business Development'
#   Position: 'sap consultant geschaeftsfuehrer gesellschafter' → Predicted: 'Other'
#
# Label 'Business Development' was incorrectly predicted 11 times:
#   Position: 'director expansi n de negocio' → Predicted: 'Marketing'
#   Position: 'busess development manager' → Predicted: 'Marketing'
#   Position: 'new busess manager' → Predicted: 'Marketing'
#   Position: 'strategic engagement manager' → Predicted: 'Marketing'
#   Position: 'global director head of portfolio and busess development global service' → Predicted: 'Marketing'
#   Position: 'head of startup engagements for s 4hana and digital supply cha' → Predicted: 'Marketing'
#   Position: 'director of busess development' → Predicted: 'Marketing'
#   Position: 'strategy director' → Predicted: 'Marketing'
#   Position: 'evp strategic partnerships' → Predicted: 'Other'
#   Position: 'busess development agent' → Predicted: 'Marketing'
#   Position: 'busess development leader' → Predicted: 'Marketing'
#
# Label 'Sales' was incorrectly predicted 46 times:
#   Position: 'gerente comercial' → Predicted: 'Other'
#   Position: 'kaufmaennischer leiter' → Predicted: 'Marketing'
#   Position: 'director sales' → Predicted: 'Marketing'
#   Position: 'chief revenue officer cro' → Predicted: 'Other'
#   Position: 'side sales' → Predicted: 'Other'
#   Position: 'key account manager' → Predicted: 'Marketing'
#   Position: 'key account manager' → Predicted: 'Marketing'
#   Position: 'account manager s lger helly hansen workwear sj lland bornholm' → Predicted: 'Marketing'
#   Position: 'district sales manager' → Predicted: 'Marketing'
#   Position: 'co head of bid management ce' → Predicted: 'Marketing'
#   Position: 'bid manager' → Predicted: 'Marketing'
#   Position: 'vertriebsdirektor' → Predicted: 'Other'
#   Position: 'regionalleiter bankenbetreuung baden wuerttemberg' → Predicted: 'Other'
#   Position: 'manager regional key accounts americas' → Predicted: 'Marketing'
#   Position: 'mediaberater dps fachzeitschrift f schaedlgsbekaempfung salesmanager dps pest control magaze' → Predicted: 'Other'
#   Position: 'abteilungsdirektor vertrieb' → Predicted: 'Other'
#   Position: 'kundansvarig' → Predicted: 'Other'
#   Position: 'marketplace manager onle shop manager' → Predicted: 'Marketing'
#   Position: 'account manager' → Predicted: 'Marketing'
#   Position: 'marktondersteung' → Predicted: 'Other'
#   Position: 'account manager' → Predicted: 'Marketing'
#   Position: 'vertrieb' → Predicted: 'Other'
#   Position: 'head of account management' → Predicted: 'Marketing'
#   Position: 'vertriebsgenieur' → Predicted: 'Other'
#   Position: 'chief sales officer cso' → Predicted: 'Other'
#   Position: 'key account manager' → Predicted: 'Marketing'
#   Position: 'senior account manager public sector' → Predicted: 'Marketing'
#   Position: 'head of sales dach' → Predicted: 'Marketing'
#   Position: 'director of sales marketg' → Predicted: 'Marketing'
#   Position: 'verkaufsleitung' → Predicted: 'Other'
#   Position: 'vice president national sales manager' → Predicted: 'Other'
#   Position: 'verkaufsmanager' → Predicted: 'Other'
#   Position: 'senior commercial manager' → Predicted: 'Marketing'
#   Position: 'abteilungsleiter vertrieb dipl bankbetriebswirt management adg' → Predicted: 'Marketing'
#   Position: 'senior director of sales sdr germany' → Predicted: 'Marketing'
#   Position: 'director of sales sdr germany' → Predicted: 'Marketing'
#   Position: 'regionaler vertriebsleiter' → Predicted: 'Other'
#   Position: 'head of sales partnerships' → Predicted: 'Marketing'
#   Position: 'vertriebsleiter' → Predicted: 'Other'
#   Position: 'regional sales manager central european region' → Predicted: 'Marketing'
#   Position: 'key account manager' → Predicted: 'Marketing'
#   Position: 'ambassador' → Predicted: 'Other'
#   Position: 'automotive sales manager' → Predicted: 'Marketing'
#   Position: 'key account director europe middle east africa' → Predicted: 'Business Development'
#   Position: 'key account director europe middle east africa' → Predicted: 'Business Development'
#   Position: 'owner cso' → Predicted: 'Other'
#
# Label 'Administrative' was incorrectly predicted 14 times:
#   Position: 'admistrador unico' → Predicted: 'Other'
#   Position: 'apl ansvarig samordng' → Predicted: 'Other'
#   Position: 'bueroleiter pressesprecher' → Predicted: 'Other'
#   Position: 'verwaltungsangestellter' → Predicted: 'Other'
#   Position: 'bueroleiter' → Predicted: 'Other'
#   Position: 'vedouc pobo ky pop vky' → Predicted: 'Other'
#   Position: 'assistent der geschaeftsleitung' → Predicted: 'Other'
#   Position: 'assistant' → Predicted: 'Other'
#   Position: 'responsable de salle' → Predicted: 'Marketing'
#   Position: 'bestuursassistent' → Predicted: 'Other'
#   Position: 'facility coordator cbre gws gmbh' → Predicted: 'Other'
#   Position: 'facility coordator' → Predicted: 'Other'
#   Position: 'office admistrator' → Predicted: 'Other'
#   Position: 'bauverwaltung' → Predicted: 'Other'
#
# Label 'Human Resources' was incorrectly predicted 16 times:
#   Position: 'human resources generalist' → Predicted: 'Marketing'
#   Position: 'head of hr chro' → Predicted: 'Marketing'
#   Position: 'traer docent' → Predicted: 'Other'
#   Position: 'personalleiter' → Predicted: 'Other'
#   Position: 'hr manager' → Predicted: 'Marketing'
#   Position: 'human resources specialist' → Predicted: 'Marketing'
#   Position: 'konsult hr' → Predicted: 'Marketing'
#   Position: 'leiter verguetung versorgung' → Predicted: 'Marketing'
#   Position: 'recruitment manager' → Predicted: 'Marketing'
#   Position: 'account manager talent acquisition lead' → Predicted: 'Marketing'
#   Position: 'hr specialist personnel development' → Predicted: 'Marketing'
#   Position: 'senior executive l d department' → Predicted: 'Marketing'
#   Position: 'gesamtleiter personal mitglied der geschaeftsleitung' → Predicted: 'Other'
#   Position: 'senior diversity clusion partner' → Predicted: 'Marketing'
#   Position: 'hr talent manager' → Predicted: 'Marketing'
#   Position: 'vice president human resources health security subscription services h3s north americas' → Predicted: 'Other'
#
# Label 'Project Management' was incorrectly predicted 38 times:
#   Position: 'projektmanager' → Predicted: 'Other'
#   Position: 'senior project manager' → Predicted: 'Marketing'
#   Position: 'senior project manager' → Predicted: 'Marketing'
#   Position: 'sub stream lead simplify turnaround programs' → Predicted: 'Other'
#   Position: 'projektmanager' → Predicted: 'Other'
#   Position: 'director of product management' → Predicted: 'Marketing'
#   Position: 'projektmanager' → Predicted: 'Other'
#   Position: 'traer coach' → Predicted: 'Marketing'
#   Position: 'project manager' → Predicted: 'Marketing'
#   Position: 'projektleiter qualitaet hv batterie' → Predicted: 'Other'
#   Position: 'project lead for swap re engeerg project' → Predicted: 'Marketing'
#   Position: 'architekt fachgebietsleitung technisches und strategisches gebaeudemanagement' → Predicted: 'Other'
#   Position: 'projektkoordator' → Predicted: 'Other'
#   Position: 'head of package stallation design igc' → Predicted: 'Marketing'
#   Position: 'senior project leader' → Predicted: 'Marketing'
#   Position: 'projektleder' → Predicted: 'Other'
#   Position: 'leiter expansion und projektentwicklung' → Predicted: 'Marketing'
#   Position: 'directeur projet' → Predicted: 'Other'
#   Position: 'chef de projet senior' → Predicted: 'Marketing'
#   Position: 'projektleiter' → Predicted: 'Other'
#   Position: 'project manager' → Predicted: 'Marketing'
#   Position: 'head of capex delivery management and planng site leverkusen' → Predicted: 'Marketing'
#   Position: 'vp product management' → Predicted: 'Marketing'
#   Position: 'produktmanager optomechanik' → Predicted: 'Other'
#   Position: 'senior manager b2b contract implementation management' → Predicted: 'Marketing'
#   Position: 'projektleiter bestandesentwicklung bei liegenschaften stadt zuerich' → Predicted: 'Other'
#   Position: 'projektleiter' → Predicted: 'Other'
#   Position: 'sub manager coordation planng' → Predicted: 'Marketing'
#   Position: 'sub manager coordation planng' → Predicted: 'Marketing'
#   Position: 'project coordator fance' → Predicted: 'Other'
#   Position: 'bauprojektleiter' → Predicted: 'Other'
#   Position: 'projektleiter bau neubauprojekte' → Predicted: 'Other'
#   Position: 'qualitaetsmanager' → Predicted: 'Other'
#   Position: 'qualitaetsmanager' → Predicted: 'Other'
#   Position: 'equipment project manager' → Predicted: 'Marketing'
#   Position: 'projektmanager therapieberufe' → Predicted: 'Other'
#   Position: 'director projects' → Predicted: 'Marketing'
#   Position: 'site manager' → Predicted: 'Marketing'
#
# Label 'Purchasing' was incorrectly predicted 15 times:
#   Position: 'purchasg manager' → Predicted: 'Marketing'
#   Position: 'procurement manager strategische koop' → Predicted: 'Marketing'
#   Position: 'strategisch koper' → Predicted: 'Other'
#   Position: 'ooe koordator fuer das team der bereiche beschlagwortung zustellproblem' → Predicted: 'Marketing'
#   Position: 'sachbearbeiter der beschlagwortung rueckpost' → Predicted: 'Other'
#   Position: 'sourcg specialist' → Predicted: 'Other'
#   Position: 'teamleitung ersatzteile' → Predicted: 'Other'
#   Position: 'purchasg manager' → Predicted: 'Marketing'
#   Position: 'strategic purchasg manager group purchasg' → Predicted: 'Marketing'
#   Position: 'head of procurement' → Predicted: 'Marketing'
#   Position: 'purchasg senior manager' → Predicted: 'Marketing'
#   Position: 'buyer' → Predicted: 'Other'
#   Position: 'vp purchasg supplier quality webasto cha' → Predicted: 'Other'
#   Position: 'advanced purchasg commercial vehicles and services' → Predicted: 'Other'
#   Position: 'buyg porecurement allocation' → Predicted: 'Other'
#
# Label 'Marketing' was incorrectly predicted 9 times:
#   Position: 'geschaeftsfuehrer cmo' → Predicted: 'Other'
#   Position: 'brand ambassador' → Predicted: 'Other'
#   Position: 'grafik designer' → Predicted: 'Other'
#   Position: 'communications coordator' → Predicted: 'Other'
#   Position: 'grafikdesigner freelance' → Predicted: 'Other'
#   Position: 'vorstandsassistent cmo' → Predicted: 'Other'
#   Position: 'executive vice president digital customer solutions' → Predicted: 'Other'
#   Position: 'referent digitale schiene' → Predicted: 'Other'
#   Position: 'digitalbeauftragte' → Predicted: 'Other'
#
# Label 'Customer Support' was incorrectly predicted 6 times:
#   Position: 'technical customer service manager flexible packagg' → Predicted: 'Marketing'
#   Position: 'senior customer care representative' → Predicted: 'Marketing'
#   Position: 'commercial service manager' → Predicted: 'Marketing'
#   Position: 'platform support direct drive' → Predicted: 'Other'
#   Position: 'bereichsleiter central service center' → Predicted: 'Other'
#   Position: 'warranty service specialist' → Predicted: 'Other'
